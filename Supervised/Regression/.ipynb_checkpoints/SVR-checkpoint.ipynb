# %% [markdown]
# ## Support Vector Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../../Datasets/Position_Salaries.csv")
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df.shape
# Out:
# (10, 3)

# %%
df.describe()
# Out:
#           Level          Salary
# count  10.00000       10.000000
# mean    5.50000   249500.000000
# std     3.02765   299373.883668
# min     1.00000    45000.000000
# 25%     3.25000    65000.000000
# 50%     5.50000   130000.000000
# 75%     7.75000   275000.000000
# max    10.00000  1000000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
df.isnull().sum()
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]
print(X)
print('--------------------***********************************------------------')
print(y)
# Out:
#             Position  Level
# 0   Business Analyst      1
# 1  Junior Consultant      2
# 2  Senior Consultant      3
# 3            Manager      4
# 4    Country Manager      5
# 5     Region Manager      6
# 6            Partner      7
# 7     Senior Partner      8
# 8            C-level      9
# 9                CEO     10
# --------------------***********************************------------------
#     Salary
# 0    45000
# 1    50000
# 2    60000
# 3    80000
# 4   110000
# 5   150000
# 6   200000
# 7   300000
# 8   500000
# 9  1000000

# %%
y = y.reshape(-1,1)

# %%
y
# Out:
#     Salary
# 0    45000
# 1    50000
# 2    60000
# 3    80000
# 4   110000
# 5   150000
# 6   200000
# 7   300000
# 8   500000
# 9  1000000

# %%
X.shape
# Out:
# (10, 2)

# %%
le = preprocessing.LabelEncoder()
X_to_encode = X.iloc[:, 0]
le.fit(X_to_encode)
X_encoded = le.transform(X_to_encode)

# %%
X_encoded
# Out:
#    0
# 0  0
# 1  4
# 2  8
# 3  5
# 4  3
# 5  7
# 6  6
# 7  9
# 8  1
# 9  2

# %%
X_encoded = pd.DataFrame(X_encoded)

merged_df = X.merge(X_encoded_df, left_on=X.iloc[:, 1], right_on='encoded_column_name')

# %%
sc = StandardScaler()
X = sc.fit_transform(X_encoded)
y = sc.fit_transform(y)

# %%
regressor = SVR(kernel='rbf')
regressor.fit(X,y)
# Out:
# SVR()

# %%
y_pred = regressor.predict([[6.5]]).reshape(-1,1)
y_pred = sc.inverse_transform(y_pred)
y_pred
# Out:
# array([[-0.21079454]])

# %%
# %matplotlib inline

# %%
plt.scatter(X, y, color = 'red')
plt.scatter(X, regressor.predict(X), color = 'blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
